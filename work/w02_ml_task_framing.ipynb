# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hassan-tech-pro/ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Task Type: Classification (and Regression scoring for metric trade-offs)
# The core predictive task of the underlying target model is Classification (predicting discrete class labels from input features). However, when evaluating compression, the meta-task operates as Scoring/Regression quantifying continuous target outputs such as accuracy loss percentage, latency in milliseconds, and memory reduction ratio across different pruning or quantization hyperparameter configurations. Framing it this way ensures we evaluate both label predictive performance and efficiency trade-off scores simultaneously.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# What would you predict?
# I am predicting the discrete target label (e.g., classification class) for each data sample in the test dataset using both baseline and compressed models.

# Where does that label come from. observed outcome or a defined rule?
# The ground truth label comes from observed outcomes in the dataset (ground truth labels assigned during data collection). In the context of model optimization, we also compare compressed predictions against the baseline uncompressed model's logits to measure compression drift.
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# One metric you can defend:
# Macro F1-Score Retention Ratio (or Accuracy Retention) combined with Inference Latency Speedup (ms/sample).

# What number means 'good'?
# A compressed model achieves "good" performance if it preserves at least 90% of the baseline F1-Score while achieving at least a 2x reduction in model parameter memory footprint (MB) or 1.5x speedup in inference latency.
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).

# One row = One individual data instance / observation (e.g a single record with feature vectors evaluated by the baseline and compressed neural network models).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).

# High-Dimensional Feature Interactions: Non-linear decision boundaries between multiple feature vectors cannot be captured by simple hand-crafted heuristics or nested logic rules without losing critical signals.
# Non-Linear Compression Dynamics: Pruning weights or quantizing layer parameters affects model activations non-linearly. A fixed rule like "if weight < 0.01, set to 0" ignores cross-layer weight interactions and results in catastrophic accuracy drops. Machine learning models adaptively map these complex representations to preserve performance.

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
